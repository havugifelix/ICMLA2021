# %% [markdown]
# #paper2017---Original
# - We're going to be training this on the simpsons character dataset

# %%
from tensorflow import keras
# import keras
from tensorflow.keras import regularizers
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential,load_model
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, BatchNormalization
from tensorflow.keras.layers import Conv2D, MaxPooling2D
# from tensorflow.keras.layers.advanced_activations import ELU
from sklearn.utils import class_weight
# from keras.utils.vis_utils import plot_model
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import os
from collections import Counter
import numpy as np
from tensorflow.keras.optimizers import RMSprop, SGD, Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from sklearn.utils.multiclass import unique_labels

# from vis.utils import utils
# from keras import activations

# %%
#### from __future__ import print_function


num_classes = 4
img_rows, img_cols = 224,224
batch_size =32
train_data_dir = "/home/kashraf/felix_hd/data_gen_may_2021/Audio_topomaps_June21/stack/train/"
validation_data_dir ="/home/kashraf/felix_hd/data_gen_may_2021/Audio_topomaps_June21/stack/test/"

# Let's use some data augmentaiton 
train_datagen = ImageDataGenerator()
#rescale=1./255)
validation_datagen = ImageDataGenerator()
 
train_generator = train_datagen.flow_from_directory(
    train_data_dir,
    target_size=(img_rows, img_cols),
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=True)

validation_generator = validation_datagen.flow_from_directory(
    validation_data_dir,
    target_size=(img_rows, img_cols),
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False)
nb_train_samples = 26800
nb_validation_samples = 11008
# Out:
# Found 26800 images belonging to 4 classes.
# Found 11008 images belonging to 4 classes.

# %%
# class_weights = class_weight.compute_class_weight(
#                'balanced',
#                 np.unique(train_generator.classes), 
#                 train_generator.classes)
# print(class_weights)

# %%
def plot_confusion_matrix(y_true, y_pred, classes,name,
                          normalize=False,
                          title=None,
                          cmap=plt.cm.Blues):
    if not title:
        if normalize:
            title = ''
        else:
            title = ''
    cm = confusion_matrix(y_true, y_pred)
    classes = classes[unique_labels(y_true, y_pred)]
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')
    print(cm)
    fig, ax = plt.subplots()
    im = ax.imshow(cm, interpolation='nearest', cmap=cmap)
    ax.figure.colorbar(im, ax=ax)
    ax.set(xticks=np.arange(cm.shape[1]),
           yticks=np.arange(cm.shape[0]),
           xticklabels=classes, yticklabels=classes,
           title=title,
           ylabel='True label',
           xlabel='Predicted label')
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
             rotation_mode="anchor")
    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], fmt),
                    ha="center", va="center",
                    color="white" if cm[i, j] > thresh else "black")
    plt.tight_layout()
    plt.savefig(name, dpi = 1200)
    return ax

# %% [markdown]
# ## Let's create our LittleVGG Model

# %%
model = Sequential()

# First CONV-ReLU Layer
model.add(Conv2D(32, (7, 7), padding = 'same', input_shape = (img_rows, img_cols,3)))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

# Second CONV-ReLU Layer
model.add(Conv2D(64, (5, 5), padding = "same"))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(96, (3, 3), padding="same"))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.4))

model.add(Conv2D(128, (3, 3), padding="same",kernel_regularizer=regularizers.l2(0.01)))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(256, (3, 3), padding="same",kernel_regularizer=regularizers.l2(0.01)))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(256, (3, 3), padding="same",kernel_regularizer=regularizers.l2(0.01)))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())

model.add(Dense(1024))
model.add(Activation('relu'))
model.add(Dropout(0.4))


# Final Dense Layer
model.add(Dense(num_classes,activation='softmax',name='mbm'))

print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 224, 224, 32)      4736
# _________________________________________________________________
# batch_normalization (BatchNo (None, 224, 224, 32)      128
# _________________________________________________________________
# activation (Activation)      (None, 224, 224, 32)      0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 112, 112, 32)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 112, 112, 64)      51264
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 112, 112, 64)      256
# _________________________________________________________________
# activation_1 (Activation)    (None, 112, 112, 64)      0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 56, 56, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 56, 56, 96)        55392
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 56, 56, 96)        384
# _________________________________________________________________
# activation_2 (Activation)    (None, 56, 56, 96)        0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 28, 28, 96)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 28, 28, 96)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 28, 28, 128)       110720
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 28, 28, 128)       512
# _________________________________________________________________
# activation_3 (Activation)    (None, 28, 28, 128)       0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 14, 14, 128)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 14, 14, 256)       295168
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 14, 14, 256)       1024
# _________________________________________________________________
# activation_4 (Activation)    (None, 14, 14, 256)       0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 7, 7, 256)         0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 7, 7, 256)         590080
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 7, 7, 256)         1024
# _________________________________________________________________
# activation_5 (Activation)    (None, 7, 7, 256)         0
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 3, 3, 256)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 2304)              0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              2360320
# _________________________________________________________________
# activation_6 (Activation)    (None, 1024)              0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# mbm (Dense)                  (None, 4)                 4100
# =================================================================
# Total params: 3,475,108
# Trainable params: 3,473,444
# Non-trainable params: 1,664
# _________________________________________________________________
# None

# %%
# %matplotlib inline
plot_model(model, to_file='LittleVGG.png', show_shapes=True, show_layer_names=True)
img = mpimg.imread('LittleVGG.png')
plt.figure(figsize=(100,70))
plt.show()

# %% [markdown]
# ### Training our LittleVGG Model!

# %%
             
checkpoint = ModelCheckpoint("/home/kashraf/Research_2021/saved_models/cnn_stack_jun28-v1.h5",
                             monitor="val_loss",
                             mode="min",
                             save_best_only = True,
                             verbose=1)

earlystop = EarlyStopping(monitor = 'val_loss', 
                          min_delta = 0, 
                          patience = 7,
                          verbose = 1,
                          restore_best_weights = True)

reduce_lr = ReduceLROnPlateau(monitor = 'val_loss',
                              factor = 0.2,
                              patience = 3,
                              verbose = 1,
                              min_delta = 0.000001)

# we put our call backs into a callback list
callbacks = [ checkpoint,reduce_lr]

# We use a very small learning rate 
model.compile(loss = 'categorical_crossentropy',
              optimizer = Adam(learning_rate=0.0001),
              metrics = ['accuracy'])


epochs = 100

history= model.fit(   
    
    train_generator,
    steps_per_epoch = nb_train_samples // batch_size,
    epochs = epochs,
    callbacks = callbacks,
    validation_data = validation_generator,
    validation_steps = nb_validation_samples // batch_size)
# Out:
# Epoch 1/100
# 837/837 [==============================] - 1324s 2s/step - loss: 5.9384 - accuracy: 0.3164 - val_loss: 4.8331 - val_accuracy: 0.3780
#
# Epoch 00001: val_loss improved from inf to 4.83314, saving model to /home/kashraf/Research_2021/saved_models/cnn_stack_jun28-v1.h5
# Epoch 2/100
# 837/837 [==============================] - 1252s 1s/step - loss: 3.8736 - accuracy: 0.4348 - val_loss: 3.1708 - val_accuracy: 0.4137
#
# Epoch 00002: val_loss improved from 4.83314 to 3.17075, saving model to /home/kashraf/Research_2021/saved_models/cnn_stack_jun28-v1.h5
# Epoch 3/100
# 837/837 [==============================] - 1253s 1s/step - loss: 2.4761 - accuracy: 0.5478 - val_loss: 2.1010 - val_accuracy: 0.5450
#
# Epoch 00003: val_loss improved from 3.17075 to 2.10104, saving model to /home/kashraf/Research_2021/saved_models/cnn_stack_jun28-v1.h5
# Epoch 4/100
# 837/837 [==============================] - 1252s 1s/step - loss: 1.7149 - accuracy: 0.6427 - val_loss: 1.5404 - val_accuracy: 0.6592
#
# Epoch 00004: val_loss improved from 2.10104 to 1.54041, saving model to /home/kashraf/Research_2021/saved_models/cnn_stack_jun28-v1.h5
# Epoch 5/100
# 837/837 [==============================] - 1253s 1s/step - loss: 1.2962 - accuracy: 0.7155 - val_loss: 1.4022 - val_accuracy: 0.6441
#
# Epoch 00005: val_loss improved from 1.54041 to 1.40217, saving model to /home/kashraf/Research_2021/saved_models/cnn_stack_jun28-v1.h5
# Epoch 6/100
# 837/837 [==============================] - 1253s 1s/step - loss: 1.0469 - accuracy: 0.7652 - val_loss: 0.9906 - val_accuracy: 0.7762
#
# Epoch 00006: val_loss improved from 1.40217 to 0.99056, saving model to /home/kashraf/Research_2021/saved_models/cnn_stack_jun28-v1.h5
# Epoch 7/100
# 837/837 [==============================] - 1252s 1s/step - loss: 0.9031 - accuracy: 0.7972 - val_loss: 0.9327 - val_accuracy: 0.7683
#
# Epoch 00007: val_loss improved from 0.99056 to 0.93268, saving model to /home/kashraf/Research_2021/saved_models/cnn_stack_jun28-v1.h5
# Epoch 8/100
# 837/837 [==============================] - 1252s 1s/step - loss: 0.7960 - accuracy: 0.8267 - val_loss: 0.8423 - val_accuracy: 0.7987
#
# Epoch 00008: val_loss improved from 0.93268 to 0.84226, saving model to /home/kashraf/Research_2021/saved_models/cnn_stack_jun28-v1.h5
# Epoch 9/100
# 837/837 [==============================] - 1252s 1s/step - loss: 0.7199 - accuracy: 0.8450 - val_loss: 0.8399 - val_accuracy: 0.7917
#
# Epoch 00009: val_loss improved from 0.84226 to 0.83993, saving model to /home/kashraf/Research_2021/saved_models/cnn_stack_jun28-v1.h5
# Epoch 10/100
# 837/837 [==============================] - 1252s 1s/step - loss: 0.6611 - accuracy: 0.8643 - val_loss: 0.9248 - val_accuracy: 0.7437
#
# Epoch 00010: val_loss did not improve from 0.83993
# Epoch 11/100
# 837/837 [==============================] - 1252s 1s/step - loss: 0.6194 - accuracy: 0.8772 - val_loss: 0.8697 - val_accuracy: 0.7607
#
# Epoch 00011: val_loss did not improve from 0.83993
# Epoch 12/100
# 837/837 [==============================] - 1252s 1s/step - loss: 0.5897 - accuracy: 0.8844 - val_loss: 1.1565 - val_accuracy: 0.6503
#
# Epoch 00012: val_loss did not improve from 0.83993
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 1.9999999494757503e-05.
# Epoch 13/100
# 837/837 [==============================] - 1252s 1s/step - loss: 0.4438 - accuracy: 0.9441 - val_loss: 0.6215 - val_accuracy: 0.8740
#
# Epoch 00013: val_loss improved from 0.83993 to 0.62146, saving model to /home/kashraf/Research_2021/saved_models/cnn_stack_jun28-v1.h5
# Epoch 14/100
# 837/837 [==============================] - 1253s 1s/step - loss: 0.3851 - accuracy: 0.9595 - val_loss: 0.6081 - val_accuracy: 0.8802
#
# Epoch 00014: val_loss improved from 0.62146 to 0.60812, saving model to /home/kashraf/Research_2021/saved_models/cnn_stack_jun28-v1.h5
# Epoch 15/100
# 837/837 [==============================] - 1252s 1s/step - loss: 0.3538 - accuracy: 0.9660 - val_loss: 0.5883 - val_accuracy: 0.8835
#
# Epoch 00015: val_loss improved from 0.60812 to 0.58834, saving model to /home/kashraf/Research_2021/saved_models/cnn_stack_jun28-v1.h5
# Epoch 16/100
# 837/837 [==============================] - 1252s 1s/step - loss: 0.3253 - accuracy: 0.9718 - val_loss: 0.5761 - val_accuracy: 0.8876
#
# Epoch 00016: val_loss improved from 0.58834 to 0.57612, saving model to /home/kashraf/Research_2021/saved_models/cnn_stack_jun28-v1.h5
# Epoch 17/100
# 837/837 [==============================] - 1252s 1s/step - loss: 0.3084 - accuracy: 0.9736 - val_loss: 0.6302 - val_accuracy: 0.8727
#
# Epoch 00017: val_loss did not improve from 0.57612
# Epoch 18/100
# 837/837 [==============================] - 1252s 1s/step - loss: 0.2921 - accuracy: 0.9759 - val_loss: 0.5785 - val_accuracy: 0.8850
#
# Epoch 00018: val_loss did not improve from 0.57612
# Epoch 19/100
# 837/837 [==============================] - 1252s 1s/step - loss: 0.2780 - accuracy: 0.9771 - val_loss: 0.5817 - val_accuracy: 0.8842
#
# Epoch 00019: val_loss did not improve from 0.57612
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 3.999999898951501e-06.
# Epoch 20/100
# 837/837 [==============================] - 1251s 1s/step - loss: 0.2500 - accuracy: 0.9875 - val_loss: 0.5621 - val_accuracy: 0.8919
#
# Epoch 00020: val_loss improved from 0.57612 to 0.56206, saving model to /home/kashraf/Research_2021/saved_models/cnn_stack_jun28-v1.h5
# Epoch 21/100
# 837/837 [==============================] - 1251s 1s/step - loss: 0.2417 - accuracy: 0.9896 - val_loss: 0.5661 - val_accuracy: 0.8931
#
# Epoch 00021: val_loss did not improve from 0.56206
# Epoch 22/100
# 837/837 [==============================] - 1251s 1s/step - loss: 0.2370 - accuracy: 0.9899 - val_loss: 0.5618 - val_accuracy: 0.8963
#
# Epoch 00022: val_loss improved from 0.56206 to 0.56183, saving model to /home/kashraf/Research_2021/saved_models/cnn_stack_jun28-v1.h5
# Epoch 23/100
# 837/837 [==============================] - 1255s 1s/step - loss: 0.2300 - accuracy: 0.9916 - val_loss: 0.5617 - val_accuracy: 0.8961
#
# Epoch 00023: val_loss improved from 0.56183 to 0.56175, saving model to /home/kashraf/Research_2021/saved_models/cnn_stack_jun28-v1.h5
# Epoch 24/100
# 837/837 [==============================] - 1259s 2s/step - loss: 0.2250 - accuracy: 0.9917 - val_loss: 0.5562 - val_accuracy: 0.8961
#
# Epoch 00024: val_loss improved from 0.56175 to 0.55618, saving model to /home/kashraf/Research_2021/saved_models/cnn_stack_jun28-v1.h5
# Epoch 25/100
# 837/837 [==============================] - 1258s 2s/step - loss: 0.2214 - accuracy: 0.9922 - val_loss: 0.5823 - val_accuracy: 0.8940
#
# Epoch 00025: val_loss did not improve from 0.55618
# Epoch 26/100
# 837/837 [==============================] - 1302s 2s/step - loss: 0.2185 - accuracy: 0.9919 - val_loss: 0.5555 - val_accuracy: 0.9001
#
# Epoch 00026: val_loss improved from 0.55618 to 0.55549, saving model to /home/kashraf/Research_2021/saved_models/cnn_stack_jun28-v1.h5
# Epoch 27/100
# 837/837 [==============================] - 1258s 2s/step - loss: 0.2132 - accuracy: 0.9931 - val_loss: 0.5581 - val_accuracy: 0.8953
#
# Epoch 00027: val_loss did not improve from 0.55549
# Epoch 28/100
# 837/837 [==============================] - 1258s 2s/step - loss: 0.2091 - accuracy: 0.9942 - val_loss: 0.5660 - val_accuracy: 0.8963
#
# Epoch 00028: val_loss did not improve from 0.55549
# Epoch 29/100
# 837/837 [==============================] - 1258s 2s/step - loss: 0.2060 - accuracy: 0.9932 - val_loss: 0.5687 - val_accuracy: 0.8960
#
# Epoch 00029: val_loss did not improve from 0.55549
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 7.999999979801942e-07.
# Epoch 30/100
# 837/837 [==============================] - 1260s 2s/step - loss: 0.2022 - accuracy: 0.9943 - val_loss: 0.5703 - val_accuracy: 0.8980
#
# Epoch 00030: val_loss did not improve from 0.55549
# Epoch 31/100
# 837/837 [==============================] - 1275s 2s/step - loss: 0.2000 - accuracy: 0.9955 - val_loss: 0.5633 - val_accuracy: 0.8987
#
# Epoch 00031: val_loss did not improve from 0.55549
# Epoch 32/100
# 837/837 [==============================] - 1242s 1s/step - loss: 0.1993 - accuracy: 0.9954 - val_loss: 0.5575 - val_accuracy: 0.9000
#
# Epoch 00032: val_loss did not improve from 0.55549
#
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 1.600000018697756e-07.
# Epoch 33/100
# 837/837 [==============================] - 1239s 1s/step - loss: 0.1980 - accuracy: 0.9955 - val_loss: 0.5603 - val_accuracy: 0.8998
#
# Epoch 00033: val_loss did not improve from 0.55549
# Epoch 34/100
# 837/837 [==============================] - 1240s 1s/step - loss: 0.1976 - accuracy: 0.9962 - val_loss: 0.5593 - val_accuracy: 0.8998
#
# Epoch 00034: val_loss did not improve from 0.55549
# Epoch 35/100
# 837/837 [==============================] - 1240s 1s/step - loss: 0.1967 - accuracy: 0.9963 - val_loss: 0.5609 - val_accuracy: 0.8998
#
# Epoch 00035: val_loss did not improve from 0.55549
#
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 3.199999980552093e-08.
# Epoch 36/100
# 837/837 [==============================] - 1240s 1s/step - loss: 0.1970 - accuracy: 0.9966 - val_loss: 0.5603 - val_accuracy: 0.8996
#
# Epoch 00036: val_loss did not improve from 0.55549
# Epoch 37/100
# 837/837 [==============================] - 1240s 1s/step - loss: 0.1974 - accuracy: 0.9958 - val_loss: 0.5606 - val_accuracy: 0.8995
#
# Epoch 00037: val_loss did not improve from 0.55549
# Epoch 38/100
# 837/837 [==============================] - 1242s 1s/step - loss: 0.1976 - accuracy: 0.9957 - val_loss: 0.5608 - val_accuracy: 0.8995
#
# Epoch 00038: val_loss did not improve from 0.55549
#
# Epoch 00038: ReduceLROnPlateau reducing learning rate to 6.399999818995639e-09.
# Epoch 39/100
# 837/837 [==============================] - 1241s 1s/step - loss: 0.1972 - accuracy: 0.9962 - val_loss: 0.5613 - val_accuracy: 0.8995
#
# Epoch 00039: val_loss did not improve from 0.55549
# Epoch 40/100
# 837/837 [==============================] - 1241s 1s/step - loss: 0.1974 - accuracy: 0.9955 - val_loss: 0.5610 - val_accuracy: 0.8996
#
# Epoch 00040: val_loss did not improve from 0.55549
# Epoch 41/100
# 837/837 [==============================] - 1241s 1s/step - loss: 0.1975 - accuracy: 0.9957 - val_loss: 0.5613 - val_accuracy: 0.8993
#
# Epoch 00041: val_loss did not improve from 0.55549
#
# Epoch 00041: ReduceLROnPlateau reducing learning rate to 1.279999928271991e-09.
# Epoch 42/100
# 837/837 [==============================] - 1245s 1s/step - loss: 0.1973 - accuracy: 0.9962 - val_loss: 0.5612 - val_accuracy: 0.8992
#
# Epoch 00042: val_loss did not improve from 0.55549
# Epoch 43/100
# 837/837 [==============================] - 1257s 2s/step - loss: 0.1969 - accuracy: 0.9963 - val_loss: 0.5613 - val_accuracy: 0.8995
#
# Epoch 00043: val_loss did not improve from 0.55549
# Epoch 44/100
# 837/837 [==============================] - 1429s 2s/step - loss: 0.1971 - accuracy: 0.9958 - val_loss: 0.5612 - val_accuracy: 0.8993
#
# Epoch 00044: val_loss did not improve from 0.55549
#
# Epoch 00044: ReduceLROnPlateau reducing learning rate to 2.55999976772614e-10.
# Epoch 45/100
# 837/837 [==============================] - 1507s 2s/step - loss: 0.1971 - accuracy: 0.9964 - val_loss: 0.5613 - val_accuracy: 0.8995
#
# Epoch 00045: val_loss did not improve from 0.55549
# Epoch 46/100
# 837/837 [==============================] - 1330s 2s/step - loss: 0.1978 - accuracy: 0.9960 - val_loss: 0.5612 - val_accuracy: 0.8993
#
# Epoch 00046: val_loss did not improve from 0.55549
# Epoch 47/100
# 837/837 [==============================] - 1249s 1s/step - loss: 0.1963 - accuracy: 0.9964 - val_loss: 0.5610 - val_accuracy: 0.8993
#
# Epoch 00047: val_loss did not improve from 0.55549
#
# Epoch 00047: ReduceLROnPlateau reducing learning rate to 5.119999424429978e-11.
# Epoch 48/100
# 837/837 [==============================] - 1249s 1s/step - loss: 0.1963 - accuracy: 0.9964 - val_loss: 0.5615 - val_accuracy: 0.8995
#
# Epoch 00048: val_loss did not improve from 0.55549
# Epoch 49/100
# 837/837 [==============================] - 1248s 1s/step - loss: 0.1969 - accuracy: 0.9959 - val_loss: 0.5617 - val_accuracy: 0.8994
#
# Epoch 00049: val_loss did not improve from 0.55549
# Epoch 50/100
# 837/837 [==============================] - 1249s 1s/step - loss: 0.1962 - accuracy: 0.9960 - val_loss: 0.5611 - val_accuracy: 0.8995
#
# Epoch 00050: val_loss did not improve from 0.55549
#
# Epoch 00050: ReduceLROnPlateau reducing learning rate to 1.0239999126415712e-11.
# Epoch 51/100
# 837/837 [==============================] - 1248s 1s/step - loss: 0.1971 - accuracy: 0.9959 - val_loss: 0.5609 - val_accuracy: 0.8993
#
# Epoch 00051: val_loss did not improve from 0.55549
# Epoch 52/100
# 837/837 [==============================] - 1249s 1s/step - loss: 0.1962 - accuracy: 0.9962 - val_loss: 0.5607 - val_accuracy: 0.8993
#
# Epoch 00052: val_loss did not improve from 0.55549
# Epoch 53/100
# 837/837 [==============================] - 1246s 1s/step - loss: 0.1972 - accuracy: 0.9959 - val_loss: 0.5619 - val_accuracy: 0.8993
#
# Epoch 00053: val_loss did not improve from 0.55549
#
# Epoch 00053: ReduceLROnPlateau reducing learning rate to 2.0479997905886727e-12.
# Epoch 54/100
# 837/837 [==============================] - 1269s 2s/step - loss: 0.1971 - accuracy: 0.9961 - val_loss: 0.5614 - val_accuracy: 0.8993
#
# Epoch 00054: val_loss did not improve from 0.55549
# Epoch 55/100
# 837/837 [==============================] - 1385s 2s/step - loss: 0.1966 - accuracy: 0.9964 - val_loss: 0.5612 - val_accuracy: 0.8993
#
# Epoch 00055: val_loss did not improve from 0.55549
# Epoch 56/100
# 837/837 [==============================] - 1350s 2s/step - loss: 0.1967 - accuracy: 0.9965 - val_loss: 0.5615 - val_accuracy: 0.8995
#
# Epoch 00056: val_loss did not improve from 0.55549
#
# Epoch 00056: ReduceLROnPlateau reducing learning rate to 4.0959995811773456e-13.
# Epoch 57/100
# 837/837 [==============================] - 1247s 1s/step - loss: 0.1967 - accuracy: 0.9963 - val_loss: 0.5604 - val_accuracy: 0.8993
#
# Epoch 00057: val_loss did not improve from 0.55549
# Epoch 58/100
# 837/837 [==============================] - 1247s 1s/step - loss: 0.1968 - accuracy: 0.9959 - val_loss: 0.5612 - val_accuracy: 0.8993
#
# Epoch 00058: val_loss did not improve from 0.55549
# Epoch 59/100
# 837/837 [==============================] - 1247s 1s/step - loss: 0.1965 - accuracy: 0.9958 - val_loss: 0.5609 - val_accuracy: 0.8995
#
# Epoch 00059: val_loss did not improve from 0.55549
#
# Epoch 00059: ReduceLROnPlateau reducing learning rate to 8.191999053934474e-14.
# Epoch 60/100
# 837/837 [==============================] - 1248s 1s/step - loss: 0.1973 - accuracy: 0.9961 - val_loss: 0.5615 - val_accuracy: 0.8995
#
# Epoch 00060: val_loss did not improve from 0.55549
# Epoch 61/100
# 837/837 [==============================] - 1248s 1s/step - loss: 0.1959 - accuracy: 0.9964 - val_loss: 0.5603 - val_accuracy: 0.8993
#
# Epoch 00061: val_loss did not improve from 0.55549
# Epoch 62/100
# 837/837 [==============================] - 1248s 1s/step - loss: 0.1970 - accuracy: 0.9960 - val_loss: 0.5616 - val_accuracy: 0.8994
#
# Epoch 00062: val_loss did not improve from 0.55549
#
# Epoch 00062: ReduceLROnPlateau reducing learning rate to 1.638399837891949e-14.
# Epoch 63/100
# 837/837 [==============================] - 1252s 1s/step - loss: 0.1959 - accuracy: 0.9966 - val_loss: 0.5612 - val_accuracy: 0.8993
#
# Epoch 00063: val_loss did not improve from 0.55549
# Epoch 64/100
# 837/837 [==============================] - 1247s 1s/step - loss: 0.1970 - accuracy: 0.9961 - val_loss: 0.5616 - val_accuracy: 0.8996
#
# Epoch 00064: val_loss did not improve from 0.55549
# Epoch 65/100
# 837/837 [==============================] - 1247s 1s/step - loss: 0.1968 - accuracy: 0.9961 - val_loss: 0.5613 - val_accuracy: 0.8994
#
# Epoch 00065: val_loss did not improve from 0.55549
#
# Epoch 00065: ReduceLROnPlateau reducing learning rate to 3.27679981130917e-15.
# Epoch 66/100
# 837/837 [==============================] - 1247s 1s/step - loss: 0.1976 - accuracy: 0.9959 - val_loss: 0.5614 - val_accuracy: 0.8993
#
# Epoch 00066: val_loss did not improve from 0.55549
# Epoch 67/100
# 837/837 [==============================] - 1247s 1s/step - loss: 0.1969 - accuracy: 0.9963 - val_loss: 0.5611 - val_accuracy: 0.8993
#
# Epoch 00067: val_loss did not improve from 0.55549
# Epoch 68/100
# 837/837 [==============================] - 1247s 1s/step - loss: 0.1976 - accuracy: 0.9959 - val_loss: 0.5614 - val_accuracy: 0.8994
#
# Epoch 00068: val_loss did not improve from 0.55549
#
# Epoch 00068: ReduceLROnPlateau reducing learning rate to 6.553599792024929e-16.
# Epoch 69/100
# 837/837 [==============================] - 1247s 1s/step - loss: 0.1967 - accuracy: 0.9962 - val_loss: 0.5609 - val_accuracy: 0.8993
# Epoch 00069: val_loss did not improve from 0.55549
# Epoch 70/100
# 837/837 [==============================] - 1247s 1s/step - loss: 0.1970 - accuracy: 0.9963 - val_loss: 0.5608 - val_accuracy: 0.8996
#
# Epoch 00070: val_loss did not improve from 0.55549
# Epoch 71/100
# 837/837 [==============================] - 1247s 1s/step - loss: 0.1973 - accuracy: 0.9960 - val_loss: 0.5613 - val_accuracy: 0.8993
#
# Epoch 00071: val_loss did not improve from 0.55549
#
# Epoch 00071: ReduceLROnPlateau reducing learning rate to 1.3107199584049857e-16.
# Epoch 72/100
# 837/837 [==============================] - 1248s 1s/step - loss: 0.1973 - accuracy: 0.9959 - val_loss: 0.5615 - val_accuracy: 0.8993
#
# Epoch 00072: val_loss did not improve from 0.55549
# Epoch 73/100
# 837/837 [==============================] - 1248s 1s/step - loss: 0.1966 - accuracy: 0.9961 - val_loss: 0.5614 - val_accuracy: 0.8993
#
# Epoch 00073: val_loss did not improve from 0.55549
# Epoch 74/100
# 837/837 [==============================] - 1248s 1s/step - loss: 0.1968 - accuracy: 0.9961 - val_loss: 0.5607 - val_accuracy: 0.8994
#
# Epoch 00074: val_loss did not improve from 0.55549
#
# Epoch 00074: ReduceLROnPlateau reducing learning rate to 2.6214399168099714e-17.
# Epoch 75/100
# 837/837 [==============================] - 1248s 1s/step - loss: 0.1966 - accuracy: 0.9957 - val_loss: 0.5610 - val_accuracy: 0.8995
#
# Epoch 00075: val_loss did not improve from 0.55549
# Epoch 76/100
# 837/837 [==============================] - 1248s 1s/step - loss: 0.1970 - accuracy: 0.9963 - val_loss: 0.5612 - val_accuracy: 0.8996
#
# Epoch 00076: val_loss did not improve from 0.55549
# Epoch 77/100
# 837/837 [==============================] - 1248s 1s/step - loss: 0.1971 - accuracy: 0.9960 - val_loss: 0.5616 - val_accuracy: 0.8995
#
# Epoch 00077: val_loss did not improve from 0.55549
#
# Epoch 00077: ReduceLROnPlateau reducing learning rate to 5.2428798336199434e-18.
# Epoch 78/100
# 837/837 [==============================] - 1247s 1s/step - loss: 0.1963 - accuracy: 0.9963 - val_loss: 0.5613 - val_accuracy: 0.8993
#
# Epoch 00078: val_loss did not improve from 0.55549
# Epoch 79/100
# 837/837 [==============================] - 1248s 1s/step - loss: 0.1966 - accuracy: 0.9961 - val_loss: 0.5609 - val_accuracy: 0.8994
#
# Epoch 00079: val_loss did not improve from 0.55549
# Epoch 80/100
# 837/837 [==============================] - 1249s 1s/step - loss: 0.1973 - accuracy: 0.9961 - val_loss: 0.5609 - val_accuracy: 0.8993
#
# Epoch 00080: val_loss did not improve from 0.55549
#
# Epoch 00080: ReduceLROnPlateau reducing learning rate to 1.0485759998112131e-18.
# Epoch 81/100
# 837/837 [==============================] - 1248s 1s/step - loss: 0.1977 - accuracy: 0.9959 - val_loss: 0.5607 - val_accuracy: 0.8993
#
# Epoch 00081: val_loss did not improve from 0.55549
# Epoch 82/100
# 837/837 [==============================] - 1248s 1s/step - loss: 0.1965 - accuracy: 0.9962 - val_loss: 0.5608 - val_accuracy: 0.8996
#
# Epoch 00082: val_loss did not improve from 0.55549
# Epoch 83/100
# 837/837 [==============================] - 1250s 1s/step - loss: 0.1974 - accuracy: 0.9960 - val_loss: 0.5608 - val_accuracy: 0.8992
#
# Epoch 00083: val_loss did not improve from 0.55549
#
# Epoch 00083: ReduceLROnPlateau reducing learning rate to 2.0971520409814568e-19.
# Epoch 84/100
# 837/837 [==============================] - 1251s 1s/step - loss: 0.1971 - accuracy: 0.9961 - val_loss: 0.5614 - val_accuracy: 0.8993
#
# Epoch 00084: val_loss did not improve from 0.55549
# Epoch 85/100
# 837/837 [==============================] - 1251s 1s/step - loss: 0.1962 - accuracy: 0.9962 - val_loss: 0.5612 - val_accuracy: 0.8994
#
# Epoch 00085: val_loss did not improve from 0.55549
# Epoch 86/100
# 837/837 [==============================] - 1251s 1s/step - loss: 0.1973 - accuracy: 0.9963 - val_loss: 0.5612 - val_accuracy: 0.8996
#
# Epoch 00086: val_loss did not improve from 0.55549
#
# Epoch 00086: ReduceLROnPlateau reducing learning rate to 4.1943040819629136e-20.
# Epoch 87/100
# 837/837 [==============================] - 1251s 1s/step - loss: 0.1977 - accuracy: 0.9951 - val_loss: 0.5617 - val_accuracy: 0.8995
#
# Epoch 00087: val_loss did not improve from 0.55549
# Epoch 88/100
# 837/837 [==============================] - 1283s 2s/step - loss: 0.1968 - accuracy: 0.9961 - val_loss: 0.5612 - val_accuracy: 0.8993
#
# Epoch 00088: val_loss did not improve from 0.55549
# Epoch 89/100
# 837/837 [==============================] - 1381s 2s/step - loss: 0.1973 - accuracy: 0.9957 - val_loss: 0.5609 - val_accuracy: 0.8993
#
# Epoch 00089: val_loss did not improve from 0.55549
#
# Epoch 00089: ReduceLROnPlateau reducing learning rate to 8.388607905431887e-21.
# Epoch 90/100
# 837/837 [==============================] - 1364s 2s/step - loss: 0.1969 - accuracy: 0.9960 - val_loss: 0.5616 - val_accuracy: 0.8993
#
# Epoch 00090: val_loss did not improve from 0.55549
# Epoch 91/100
# 837/837 [==============================] - 1257s 2s/step - loss: 0.1964 - accuracy: 0.9962 - val_loss: 0.5609 - val_accuracy: 0.8997
#
# Epoch 00091: val_loss did not improve from 0.55549
# Epoch 92/100
# 837/837 [==============================] - 1257s 2s/step - loss: 0.1981 - accuracy: 0.9956 - val_loss: 0.5608 - val_accuracy: 0.8993
#
# Epoch 00092: val_loss did not improve from 0.55549
#
# Epoch 00092: ReduceLROnPlateau reducing learning rate to 1.6777216457098625e-21.
# Epoch 93/100
# 837/837 [==============================] - 1257s 2s/step - loss: 0.1974 - accuracy: 0.9958 - val_loss: 0.5608 - val_accuracy: 0.8994
#
# Epoch 00093: val_loss did not improve from 0.55549
# Epoch 94/100
# 837/837 [==============================] - 1253s 1s/step - loss: 0.1970 - accuracy: 0.9959 - val_loss: 0.5610 - val_accuracy: 0.8993
#
# Epoch 00094: val_loss did not improve from 0.55549
# Epoch 95/100
# 837/837 [==============================] - 1253s 1s/step - loss: 0.1970 - accuracy: 0.9963 - val_loss: 0.5618 - val_accuracy: 0.8995
#
# Epoch 00095: val_loss did not improve from 0.55549
#
# Epoch 00095: ReduceLROnPlateau reducing learning rate to 3.3554432106403683e-22.
# Epoch 96/100
# 837/837 [==============================] - 1254s 1s/step - loss: 0.1969 - accuracy: 0.9958 - val_loss: 0.5612 - val_accuracy: 0.8992
#
# Epoch 00096: val_loss did not improve from 0.55549
# Epoch 97/100
# 837/837 [==============================] - 1254s 1s/step - loss: 0.1966 - accuracy: 0.9963 - val_loss: 0.5612 - val_accuracy: 0.8993
#
# Epoch 00097: val_loss did not improve from 0.55549
# Epoch 98/100
# 837/837 [==============================] - 1254s 1s/step - loss: 0.1967 - accuracy: 0.9964 - val_loss: 0.5609 - val_accuracy: 0.8993
#
# Epoch 00098: val_loss did not improve from 0.55549
#
# Epoch 00098: ReduceLROnPlateau reducing learning rate to 6.710886421280737e-23.
# Epoch 99/100
# 837/837 [==============================] - 1254s 1s/step - loss: 0.1967 - accuracy: 0.9960 - val_loss: 0.5617 - val_accuracy: 0.8993
#
# Epoch 00099: val_loss did not improve from 0.55549
# Epoch 100/100
# 837/837 [==============================] - 1254s 1s/step - loss: 0.1962 - accuracy: 0.9965 - val_loss: 0.5612 - val_accuracy: 0.8993
#
# Epoch 00100: val_loss did not improve from 0.55549

# %%
model.save("/home/kashraf/Research_2021/saved_models/cnn_stack_jun28-v1.h5")

# %% [markdown]
# ## Performance Analysis

# %%
import matplotlib.pyplot as plt
import sklearn
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np

# We need to recreate our validation generator with shuffle = false
validation_generator = validation_datagen.flow_from_directory(
        validation_data_dir,
        target_size=(img_rows, img_cols),
        batch_size=batch_size,
        class_mode='categorical',
        shuffle=False)

class_labels = validation_generator.class_indices
class_labels = {v: k for k, v in class_labels.items()}
classes = list(class_labels.values())
nb_train_samples = 29328
nb_validation_samples = 14672


#Confution Matrix and Classification Report
Y_pred = model.predict_generator(validation_generator, nb_validation_samples // batch_size)
y_pred = np.argmax(Y_pred, axis=1)

print('Confusion Matrix')
print(confusion_matrix(validation_generator.classes, y_pred))
print('Classification Report')
target_names = list(class_labels.values())
print(classification_report(validation_generator.classes, y_pred, target_names=target_names))

plt.figure(figsize=(8,8))
cnf_matrix = confusion_matrix(validation_generator.classes, y_pred)

plt.imshow(cnf_matrix, interpolation='nearest')
plt.colorbar()
tick_marks = np.arange(len(classes))
_ = plt.xticks(tick_marks, classes, rotation=90)
_ = plt.yticks(tick_marks, classes)

class_names=np.asarray(['CL-2','CL-4','CL-6','CL-8'])
# Plot non-normalized confusion matrix
plot_confusion_matrix(validation_generator.classes, y_pred, classes=class_names,title='',name='conf_matrix')
# Plot normalized confusion matrix
plot_confusion_matrix(validation_generator.classes, y_pred, classes=class_names, normalize=True,title='',name='conf_matrix_Nor')
plt.show()
# Out:
# Found 11008 images belonging to 4 classes.
# /home/kashraf/anaconda3/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py:2001: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   warnings.warn('`Model.predict_generator` is deprecated and '
# WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 458 batches). You may need to use the repeat() function when building your dataset.
# Confusion Matrix
# [[2575   30  124   23]
#  [  28 2555  149   20]
#  [ 206  176 2162  208]
#  [  21   24   99 2608]]
# Classification Report
#               precision    recall  f1-score   support
#
#          cl2       0.91      0.94      0.92      2752
#          cl4       0.92      0.93      0.92      2752
#          cl6       0.85      0.79      0.82      2752
#          cl8       0.91      0.95      0.93      2752
#
#     accuracy                           0.90     11008
#    macro avg       0.90      0.90      0.90     11008
# weighted avg       0.90      0.90      0.90     11008
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-b9790df5c72f> in <module>
#      40 class_names=np.asarray(['CL-2','CL-4','CL-6','CL-8'])
#      41 # Plot non-normalized confusion matrix
# ---> 42 plot_confusion_matrix(validation_generator.classes, y_pred, classes=class_names,title='',name='conf_matrix')
#      43 # Plot normalized confusion matrix
#      44 plot_confusion_matrix(validation_generator.classes, y_pred, classes=class_names, normalize=True,title='',name='conf_matrix_Nor')
#
# NameError: name 'plot_confusion_matrix' is not defined

# %% [markdown]
# ### Plotting our Accuracy and Loss Charts

# %%
print(history.history.keys())
# Plotting our loss charts
import matplotlib.pyplot as plt

history_dict = history.history
loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']
epochs = range(1, len(loss_values) + 1)

line1 = plt.plot(epochs, val_loss_values, label='Validation/Test Loss')
line2 = plt.plot(epochs, loss_values, label='Training Loss')
plt.setp(line1, linewidth=2.0, marker = '+', markersize=10.0)
plt.setp(line2, linewidth=2.0, marker = '4', markersize=10.0)
plt.xlabel('Epochs') 
plt.ylabel('Loss')
plt.grid(True)
plt.legend()
plt.savefig('Loss_stack.png', dpi = 1200)
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])

# %%
# Plotting our accuracy charts
import matplotlib.pyplot as plt

history_dict = history.history
acc_values = history_dict['accuracy']
val_acc_values = history_dict['val_accuracy']
epochs = range(1, len(loss_values) + 1)
line1 = plt.plot(epochs, val_acc_values, label='Validation/Test Accuracy')
line2 = plt.plot(epochs, acc_values, label='Training Accuracy')
plt.setp(line1, linewidth=2.0, marker = '+', markersize=10.0)
plt.setp(line2, linewidth=2.0, marker = '4', markersize=10.0)
plt.xlabel('Epochs') 
plt.ylabel('Accuracy')
plt.grid(True)
plt.legend()
plt.savefig('Accuracy_stack.png', dpi = 1200)
plt.show()

# %% [markdown]
# ### Evaluation on validation set

# %%
import seaborn as sr
validation_path=validation_data_dir ="/home/kashraf/felix_hd/data_gen_may_2021/Audio_topomaps_June21/stack/validation/"
validation_generator = validation_datagen.flow_from_directory(
        validation_path,
        target_size=(img_rows, img_cols),
        batch_size=batch_size,
        class_mode='categorical',
        shuffle=False)

class_labels = validation_generator.class_indices
class_labels = {v: k for k, v in class_labels.items()}
classes = list(class_labels.values())
nb_train_samples = 29328
nb_validation_samples = 6192


#Confution Matrix and Classification Report
Y_pred = model.predict(validation_generator, nb_validation_samples // batch_size)
y_pred = np.argmax(Y_pred, axis=1)
# Out:
# Found 6192 images belonging to 4 classes.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-40b263448da9> in <module>
#      18 Y_pred = model.predict(validation_generator, nb_validation_samples // batch_size)
#      19 y_pred = np.argmax(Y_pred, axis=1)
# ---> 20 conf_mat=confusion_matrix(classes,Y_pred)
#      21
#      22 conf_df=pd.DataFrame(conf_mat, index=["CL-1","CL-2","CL-3","CL-4"], columns=["CL-1","CL-2","CL-3","CL-4"])
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      71                           FutureWarning)
#      72         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 73         return f(**kwargs)
#      74     return inner_f
#      75
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py in confusion_matrix(y_true, y_pred, labels, sample_weight, normalize)
#     274
#     275     """
# --> 276     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     277     if y_type not in ("binary", "multiclass"):
#     278         raise ValueError("%s is not supported" % y_type)
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py in _check_targets(y_true, y_pred)
#      79     y_pred : array or indicator matrix
#      80     """
# ---> 81     check_consistent_length(y_true, y_pred)
#      82     type_true = type_of_target(y_true)
#      83     type_pred = type_of_target(y_pred)
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py in check_consistent_length(*arrays)
#     255     if len(uniques) > 1:
#     256         raise ValueError("Found input variables with inconsistent numbers of"
# --> 257                          " samples: %r" % [int(l) for l in lengths])
#     258
#     259
#
# ValueError: Found input variables with inconsistent numbers of samples: [4, 6192]

# %%
import pandas as pd
conf_mat=confusion_matrix(validation_generator.classes,y_pred,normalize='true')

conf_df=pd.DataFrame(conf_mat, index=["CL-1","CL-2","CL-3","CL-4"], columns=["CL-1","CL-2","CL-3","CL-4"])
# print("\nFace  accuracy =",accuracy)
# print("\n Face recognition report: \n",report)
fig=plt.figure(figsize=(8,6))
sr.heatmap(conf_df,annot=True,cmap="Blues")
# plt.title("Confusion matrix")
plt.xlabel("PREDICTED LABEL")
plt.ylabel("TRUE LABEL")
plt.savefig("Conf_mat_stack_valid")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-4d4526ed7b86> in <module>
#       1 import pandas as pd
# ----> 2 conf_mat=confusion_matrix(validation_generator.classes,y_pred,normalize='true')
#       3
#       4 conf_df=pd.DataFrame(conf_mat, index=["CL-1","CL-2","CL-3","CL-4"], columns=["CL-1","CL-2","CL-3","CL-4"])
#       5 # print("\nFace  accuracy =",accuracy)
#
# NameError: name 'confusion_matrix' is not defined

# %% [markdown]
# ##### ROC and AUC

# %%
model_stack=load_model("saved_models/cnn_stack_jun28-v1.h5")
y_pred = model_stack.predict_proba(validation_generator, nb_validation_samples // batch_size)
y_pred = np.argmax(y_pred, axis=1)
# Out:
# /home/kashraf/anaconda3/lib/python3.7/site-packages/tensorflow/python/keras/engine/sequential.py:430: UserWarning: `model.predict_proba()` is deprecated and will be removed after 2021-01-01. Please use `model.predict()` instead.
#   warnings.warn('`model.predict_proba()` is deprecated and '

# %%
from sklearn.metrics import roc_curve, auc,roc_auc_score
from sklearn.multiclass import OneVsRestClassifier
from scipy import interp
from sklearn.preprocessing import label_binarize
from  tensorflow.keras.utils import to_categorical 

Y_test=to_categorical(validation_generator.classes)
Y_pred=to_categorical(y_pred)
rocauc=roc_auc_score(Y_test,Y_pred,multi_class="ov")

# %%
rocauc
# Out:
# 0.9333817829457365

# %%
# Plot linewidth.
from itertools import cycle
lw = 2

# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
y_test=Y_test
y_score=Y_pred
n_classes=4
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_score[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Compute micro-average ROC curve and ROC area
fpr["micro"], tpr["micro"], _ = roc_curve(y_test.ravel(), y_score.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

# Compute macro-average ROC curve and ROC area

# First aggregate all false positive rates
all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))

# Then interpolate all ROC curves at this points
mean_tpr = np.zeros_like(all_fpr)
for i in range(n_classes):
    mean_tpr += interp(all_fpr, fpr[i], tpr[i])

# Finally average it and compute AUC
mean_tpr /= n_classes

fpr["macro"] = all_fpr
tpr["macro"] = mean_tpr
roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

# Plot all ROC curves
plt.figure(figsize=(10,8))
plt.figure(1)
plt.plot(fpr["micro"], tpr["micro"],
         label='micro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["micro"]),
         color='deeppink', linestyle=':', linewidth=4)

# plt.plot(fpr["macro"], tpr["macro"],
#          label='macro-average ROC curve (area = {0:0.2f})'
#                ''.format(roc_auc["macro"]),
#          color='navy', linestyle=':', linewidth=4)

colors = cycle(['aqua', 'darkorange', 'cornflowerblue'])
for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=lw,
             label='ROC curve of class CL- {0} (area = {1:0.2f})'
             ''.format(i+1, roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--', lw=lw)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
# plt.title('Some extension of Receiver operating characteristic to multi-class')
plt.legend(loc="lower right")
plt.show()

# %%
# %matplotlib inline
from keras.utils.vis_utils import plot_model
import matplotlib.image as mpimg

plot_model(model, to_file='LittleVGG.png', show_shapes=True, show_layer_names=True)
img = mpimg.imread('LittleVGG.png')
plt.figure(figsize=(100,70))
imgplot = plt.imshow(img)

# %% [markdown]
# # Activation Maximization

# %%
from vis.visualization import visualize_activation
from vis.utils import utils
from keras import activations
from matplotlib import pyplot as plt
# %matplotlib inline

plt.rcParams['figure.figsize'] = (18, 6)

# Utility to search for layer index by name. 
# Alternatively we can specify this as -1 since it corresponds to the last layer.
layer_idx = utils.find_layer_idx(model, 'mbm')

# Swap softmax with linear
model.layers[layer_idx].activation = activations.linear
model = utils.apply_modifications(model)

# This is the output node we want to maximize.
filter_idx = 0
img = visualize_activation(model, layer_idx, filter_indices=filter_idx)
#img = visualize_activation(model, layer_idx, filter_indices=filter_idx, input_range=(0., 1.), verbose=True)
for output_idx in np.arange(5):
    img = visualize_activation(model, layer_idx, filter_indices=output_idx, input_range=(0., 1.))
    plt.figure()
    plt.title('Networks perception of OA level--{}'.format(output_idx))
    plt.imshow(img[..., 0])

# %% [markdown]
# ## Visualizing Filter Patterns

# %%
from keras.preprocessing import image
import matplotlib.pyplot as plt

input_image_path = './OAI_Classification_Images/224*224/validation/level_1/  9001695 1.jpg'

# Show our input Image for Feature visualization
img1 = image.load_img(input_image_path)
plt.imshow(img1);
img_size = (224, 224)
# load imamge into a 4D Tensor, convert it to a numpy array and expand to 4 dim
img1 = image.load_img(input_image_path, target_size = img_size)
image_tensor = image.img_to_array(img1)
#print(image_tensor.shape)
image_tensor = image_tensor/255
image_tensor = np.expand_dims(image_tensor, axis=0)
#print(img.shape)

# %%
from keras import models

# Extracts the top 8 layers
layer_outputs = [layer.output for layer in model.layers[:13]]

# Creates a model that returns these outputs given the model input
activation_model = models.Model(inputs=model.input, outputs=layer_outputs)

# %%
activations = activation_model.predict(image_tensor)
first_layer_activation = activations[0]
print(first_layer_activation.shape)

# %%
for i in range(0,32):
    plt.matshow(first_layer_activation[0, :, :,i], cmap='viridis')

# %%
layer_names = []
for layer in model.layers[:13]:
    layer_names.append(layer.name)
images_per_row = 16

# Get CONV layers only
conv_layer_names = []
for layer_name in layer_names:
    if 'conv2d' in layer_name:
        conv_layer_names.append(layer_name)

for layer_name, layer_activation in zip(conv_layer_names, activations):
    n_features = layer_activation.shape[-1]
    size = layer_activation.shape[1]
    
    n_cols = n_features // images_per_row
    display_grid = np.zeros((size * n_cols, images_per_row * size))
    
    for col in range(n_cols):
        for row in range(images_per_row):
            channel_image = layer_activation[0,:, :,col * images_per_row + row]
            
            channel_image -= channel_image.mean()
            channel_image /= channel_image.std()
            channel_image *= 64
            channel_image += 128
            channel_image = np.clip(channel_image, 0, 255).astype('uint8')
            display_grid[col * size : (col + 1) * size,
            row * size : (row + 1) * size] = channel_image
            
    scale = 1. / size
    plt.figure(figsize=(scale * display_grid.shape[1],
    scale * display_grid.shape[0]))
    plt.title(layer_name)
    plt.grid(False)
    plt.imshow(display_grid, aspect='auto', cmap='viridis')
